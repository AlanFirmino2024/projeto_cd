# %% [markdown]
# <a href="https://colab.research.google.com/github/AlanFirmino2024/projeto_cd/blob/main/main_2509v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Projeto da disciplina de Tópicos de projetos 4**
#
# ##     Alan Firmino da Silva

# %% [markdown]
# # **1. Definição do problema**

# %% [markdown]
# O *dataset* utilizado nesse projeto será o **Imóveis**, proveniente do curso de Data Science da Alura (Alura é a maior escola de tecnologia do Brasil). Seu objetivo é prever os valores dos imóveis residenciais, com base nos atributos de imóveis presentes no *dataset*.
#
# Como o *dataset* possui dados de imóveis residenciais e comerciais, há a necessidade de fazer um filtro posteriormente. Outro ponto importante para salientar, é que no *dataset* há 21 atributos e usaremos apenas 14 deles.
#
# O *dataset* está em um formato não convencional (**JSON**) ao que foi visto na disciplina (**CSV**), por isso faremos um breve tutorial de como visualizar esses dados com o arquivo, apenas para conhecimento.

# %% [markdown]
# ## Tutorial de como visualizar um arquivo JSON
#
# Primeiro abra o arquivo JSON em seu computador com o bloco de notas, e copie um trecho do texto. A seguir entre no site [JSON Viewer](http://jsonviewer.stack.hu) e na aba ***Text***, cole o texto copiado, como mostrado na figura abaixo.
# ![Colar JSON Viewer.PNG](data:image/png;base64,...)
#
# Após isso, clique no botão *Format* e veremos que a estrutura do arquivo é muito similar ao do dicionário no *Python*. Como é mostrado na figura abaixo.
#
# ![Format JSON Viewer.png](data:image/png;base64,...)

# %% [markdown]
# ## Informações sobre os atributos.
#
# 1. **unidade**: Identificador único do imóvel.
# 2. **zona**: Zona ou região da cidade (bairro ou distrito) onde o imóvel está localizado.
# 3. **preco**: Preço total do imóvel.
# 4. **taxa_iptu**: Valor do IPTU.
# 5. **taxa_condo**: Valor mensal da taxa de condomínio.
# 6. **quartos**: Número de quartos no imóvel.
# 7. **banheiros**: Número de banheiros no imóvel.
# 8. **suites**: Número de suítes.
# 9. **vagas_estac**: Número de vagas de garagem disponíveis.
# 10. **areas_usuais**: Área útil do imóvel.
# 11. **area_total**: Área total do imóvel.
# 12. **andares**: Número de andares do imóvel.
# 13. **imov_por_andar**: Número de unidades (apartamentos) por andar.
# 14. **andar_imovel**: Andar específico onde o imóvel está localizado.

# %%
# Imports
import requests
import json
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as ms # para tratamento de missings
from matplotlib import cm
from pandas import set_option
from pandas.plotting import scatter_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import FunctionTransformer
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from yellowbrick.regressor import PredictionError

# %% [markdown]
# # **2. Carga dos dados**

# %%
# URL do arquivo JSON bruto no GitHub
url = "https://raw.githubusercontent.com/AlanFirmino2024/projeto_cd/main/imoveis.json"

dados_1 = pd.read_json(url, orient='columns')
dados_1.head()
# Out:
#                                                ident  \
# 0  {'customerID': '775564-BOJSMVON', 'source': 'W...
# 1  {'customerID': '660895-AUENKNYY', 'source': 'W...
# 2  {'customerID': '751522-JESYFEQL', 'source': 'W...
# 3  {'customerID': '714052-GAAEWYKS', 'source': 'W...
# 4  {'customerID': '568886-ZIBFOMCC', 'source': 'W...
#
#                                              listing
# 0  {'types': {'unit': 'Outros', 'usage': 'Residen...
# 1  {'types': {'unit': 'Apartamento', 'usage': 'Re...
# 2  {'types': {'unit': 'Outros', 'usage': 'Residen...
# 3  {'types': {'unit': 'Outros', 'usage': 'Comerci...
# 4  {'types': {'unit': 'Apartamento', 'usage': 'Re...

# %% [markdown]
# ## 2.1 Normalização dos dados

# %%
# Transformando o bloco ident do arquivo JSON em DataFrame
df1 = pd.json_normalize(dados_1.ident)
df1.head()
# Out:
#         customerID   source
# 0  775564-BOJSMVON  Website
# 1  660895-AUENKNYY  Website
# 2  751522-JESYFEQL  Website
# 3  714052-GAAEWYKS  Website
# 4  568886-ZIBFOMCC  Website

# %%
# Transformando o bloco listing do arquivo JSON em DataFrame
df2 = pd.json_normalize(dados_1.listing, sep='_')
df2.head()
# Out:
#     types_unit  types_usage    address_city  address_location_lon  \
# 0       Outros  Residencial  Rio de Janeiro            -43.413557
# 1  Apartamento  Residencial  Rio de Janeiro            -43.509141
# 2       Outros  Residencial  Rio de Janeiro            -43.646786
# 3       Outros    Comercial  Rio de Janeiro            -43.330818
# 4  Apartamento  Residencial  Rio de Janeiro            -43.480742
#
#    address_location_lat address_zone      address_neighborhood prices_price  \
# 0            -22.909429   Zona Oeste                   Taquara        45000
# 1            -22.869698   Zona Oeste                Santíssimo        45000
# 2            -22.986927   Zona Oeste        Pedra de Guaratiba        50000
# 3            -22.881977   Zona Norte                 Cascadura        45000
# 4            -23.027653   Zona Oeste  Recreio dos Bandeirantes        50000
#
#   prices_tax_iptu prices_tax_condo  features_bedrooms  features_bathrooms  \
# 0               0              150                  0                   0
# 1               0              120                  2                   1
# 2               0              100                  0                   0
# 3             346              468                  0                   1
# 4             120              400                  3                   2
#
#    features_suites  features_parkingSpaces features_usableAreas  \
# 0                0                       1                   62
# 1                0                       1                   44
# 2                0                       0                  132
# 3                0                       0                   32
# 4                1                       1                   60
#
#   features_totalAreas  features_floors  features_unitsOnTheFloor  \
# 0                  62                0                         0
# 1                   0                0                         0
# 2                 132                0                         0
# 3                  32                0                         0
# 4                   0                3                         4
#
#    features_unitFloor
# 0                   0
# 1                   0
# 2                   0
# 3                   3
# 4                   2

# %% [markdown]
# ## 2.2 Junção dos dataframes

# %%
dados = pd.concat([df1, df2], axis=1)
dados.head()
# Out:
#         customerID   source   types_unit  types_usage    address_city  \
# 0  775564-BOJSMVON  Website       Outros  Residencial  Rio de Janeiro
# 1  660895-AUENKNYY  Website  Apartamento  Residencial  Rio de Janeiro
# 2  751522-JESYFEQL  Website       Outros  Residencial  Rio de Janeiro
# 3  714052-GAAEWYKS  Website       Outros    Comercial  Rio de Janeiro
# 4  568886-ZIBFOMCC  Website  Apartamento  Residencial  Rio de Janeiro
#
#    address_location_lon  address_location_lat address_zone  \
# 0            -43.413557            -22.909429   Zona Oeste
# 1            -43.509141            -22.869698   Zona Oeste
# 2            -43.646786            -22.986927   Zona Oeste
# 3            -43.330818            -22.881977   Zona Norte
# 4            -43.480742            -23.027653   Zona Oeste
#
#        address_neighborhood prices_price  ... prices_tax_condo  \
# 0                   Taquara        45000  ...              150
# 1                Santíssimo        45000  ...              120
# 2        Pedra de Guaratiba        50000  ...              100
# 3                 Cascadura        45000  ...              468
# 4  Recreio dos Bandeirantes        50000  ...              400
#
#   features_bedrooms  features_bathrooms  features_suites  \
# 0                 0                   0                0
# 1                 2                   1                0
# 2                 0                   0                0
# 3                 0                   1                0
# 4                 3                   2                1
#
#    features_parkingSpaces  features_usableAreas features_totalAreas  \
# 0                       1                    62                  62
# 1                       1                    44                   0
# 2                       0                   132                 132
# 3                       0                    32                  32
# 4                       1                    60                   0
#
#   features_floors  features_unitsOnTheFloor  features_unitFloor
# 0               0                         0                   0
# 1               0                         0                   0
# 2               0                         0                   0
# 3               0                         0                   3
# 4               3                         4                   2
#
# [5 rows x 21 columns]

# %% [markdown]
# # **3. Análise dos dados**

# %% [markdown]
# ## 3.1. Estatísticas Descritivas
#
# Vamos iniciar examinando as dimensões do dataset, suas informações e alguns exemplos de linhas.

# %%
# Mostra as dimensões do dataset
dados.shape
# Out:
# (73615, 21)

# %%
# Mostra as informações do dataset
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73615 entries, 0 to 73614
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customerID                73615 non-null  object
#  1   source                    73615 non-null  object
#  2   types_unit                73615 non-null  object
#  3   types_usage               73615 non-null  object
#  4   address_city              73615 non-null  object
#  5   address_location_lon      73468 non-null  float64
#  6   address_location_lat      73468 non-null  float64
#  7   address_zone              73615 non-null  object
#  8   address_neighborhood      73615 non-null  object
#  9   prices_price              73615 non-null  object
#  10  prices_tax_iptu           64499 non-null  object
#  11  prices_tax_condo          67111 non-null  object
#  12  features_bedrooms         73615 non-null  int64
#  13  features_bathrooms        73615 non-null  int64
#  14  features_suites           73615 non-null  int64
#  15  features_parkingSpaces    73615 non-null  int64
#  16  features_usableAreas      73615 non-null  object
#  17  features_totalAreas       73615 non-null  object
#  18  features_floors           73615 non-null  int64
#  19  features_unitsOnTheFloor  73615 non-null  int64
#  20  features_unitFloor        73615 non-null  int64
# dtypes: float64(2), int64(7), object(12)
# memory usage: 11.8+ MB

# %%
# Mostra as 10 primeiras linhas do dataset
dados.head(10)
# Out:
#         customerID   source   types_unit  types_usage    address_city  \
# 0  775564-BOJSMVON  Website       Outros  Residencial  Rio de Janeiro
# 1  660895-AUENKNYY  Website  Apartamento  Residencial  Rio de Janeiro
# 2  751522-JESYFEQL  Website       Outros  Residencial  Rio de Janeiro
# 3  714052-GAAEWYKS  Website       Outros    Comercial  Rio de Janeiro
# 4  568886-ZIBFOMCC  Website  Apartamento  Residencial  Rio de Janeiro
# 5  526755-OBLTYTEN  Website       Outros  Residencial  Rio de Janeiro
# 6  593569-CJLMNFGW  Website       Outros    Comercial  Rio de Janeiro
# 7  989181-RYJOLMCU  Website       Outros    Comercial  Rio de Janeiro
# 8  145372-EZKAKSWM  Website       Outros    Comercial  Rio de Janeiro
# 9  792086-NWNQTDYL  Website  Apartamento  Residencial  Rio de Janeiro
#
#    address_location_lon  address_location_lat address_zone  \
# 0            -43.413557            -22.909429   Zona Oeste
# 1            -43.509141            -22.869698   Zona Oeste
# 2            -43.646786            -22.986927   Zona Oeste
# 3            -43.330818            -22.881977   Zona Norte
# 4            -43.480742            -23.027653   Zona Oeste
# 5            -43.571183            -22.966059   Zona Oeste
# 6            -43.345300            -22.939028   Zona Oeste
# 7            -43.278855            -22.841509   Zona Norte
# 8            -43.392253            -22.835609   Zona Norte
# 9            -43.253044            -22.885306   Zona Norte
#
#        address_neighborhood prices_price  ... prices_tax_condo  \
# 0                   Taquara        45000  ...              150
# 1                Santíssimo        45000  ...              120
# 2        Pedra de Guaratiba        50000  ...              100
# 3                 Cascadura        45000  ...              468
# 4  Recreio dos Bandeirantes        50000  ...              400
# 5                 Guaratiba        50000  ...                0
# 6   Freguesia (Jacarepaguá)        50000  ...              801
# 7                     Penha        50000  ...              230
# 8    Ricardo de Albuquerque        45000  ...             None
# 9               Jacarezinho        45336  ...                0
#
#   features_bedrooms  features_bathrooms  features_suites  \
# 0                 0                   0                0
# 1                 2                   1                0
# 2                 0                   0                0
# 3                 0                   1                0
# 4                 3                   2                1
# 5                 0                   0                0
# 6                 0                   1                0
# 7                 0                   1                0
# 8                 0                   0                0
# 9                 1                   1                0
#
#    features_parkingSpaces  features_usableAreas features_totalAreas  \
# 0                       1                    62                  62
# 1                       1                    44                   0
# 2                       0                   132                 132
# 3                       0                    32                  32
# 4                       1                    60                   0
# 5                       0                   200                 200
# 6                       0                    25                  25
# 7                       0                    23                  23
# 8                       0                    60                  60
# 9                       1                    33                  35
#
#   features_floors  features_unitsOnTheFloor  features_unitFloor
# 0               0                         0                   0
# 1               0                         0                   0
# 2               0                         0                   0
# 3               0                         0                   3
# 4               3                         4                   2
# 5               0                         0                   0
# 6               0                         0                   2
# 7               0                         0                   0
# 8               0                         0                   0
# 9               0                         0                   0
#
# [10 rows x 21 columns]

# %%
# Mostra as 10 últimas linhas do dataset
dados.tail(10)
# Out:
#             customerID   source   types_unit  types_usage    address_city  \
# 73605  629111-ZUUXUTKV  Website  Apartamento  Residencial  Rio de Janeiro
# 73606  171852-IMEEBBUI  Website         Casa  Residencial  Rio de Janeiro
# 73607  208599-RVPKBKWS  Website  Apartamento  Residencial  Rio de Janeiro
# 73608  967266-ZSRQSJXA  Website  Apartamento  Residencial  Rio de Janeiro
# 73609  023382-CWENJTYQ  Website         Casa  Residencial  Rio de Janeiro
# 73610  134148-MJIBCMDQ  Website         Casa  Residencial  Rio de Janeiro
# 73611  541465-QBQVXXXZ  Website         Casa  Residencial  Rio de Janeiro
# 73612  800542-BZREFTQS  Website  Apartamento  Residencial  Rio de Janeiro
# 73613  939419-ECGUNTIH  Website         Casa  Residencial  Rio de Janeiro
# 73614  610503-VULDJJZZ  Website  Apartamento  Residencial  Rio de Janeiro
#
#        address_location_lon  address_location_lat address_zone  \
# 73605            -43.206965            -22.970864     Zona Sul
# 73606            -43.250934            -22.998918     Zona Sul
# 73607            -43.190142            -22.983599     Zona Sul
# 73608            -43.227045            -22.986186     Zona Sul
# 73609            -43.417349            -23.002012   Zona Oeste
# 73610            -43.388906            -23.003960   Zona Oeste
# 73611            -43.395032            -23.000902   Zona Oeste
# 73612            -43.189682            -22.987018     Zona Sul
# 73613            -43.351836            -23.005037   Zona Oeste
# 73614            -43.317740            -23.009397   Zona Oeste
#
#       address_neighborhood prices_price  ... prices_tax_condo  \
# 73605                Lagoa     10000000  ...             6075
# 73606          São Conrado     10000000  ...             1850
# 73607           Copacabana     10000000  ...             3000
# 73608               Leblon     10000000  ...             7800
# 73609      Barra da Tijuca     10000000  ...             2373
# 73610      Barra da Tijuca     10000000  ...             2350
# 73611      Barra da Tijuca     10000000  ...             3000
# 73612           Copacabana     10000000  ...             None
# 73613      Barra da Tijuca     10000000  ...             2400
# 73614      Barra da Tijuca     10000000  ...             1800
#
#       features_bedrooms  features_bathrooms  features_suites  \
# 73605                 5                   6                5
# 73606                 3                   5                3
# 73607                 5                  10                5
# 73608                 4                   4                2
# 73609                 5                   6                5
# 73610                 5                  10                1
# 73611                 5                   7                5
# 73612                 4                   5                4
# 73613                 5                  10                5
# 73614                 5                   8                5
#
#        features_parkingSpaces  features_usableAreas features_totalAreas  \
# 73605                       4                   570                 570
# 73606                       2                  1100                1257
# 73607                       2                   680                 680
# 73608                       2                   400                 400
# 73609                       5                  1014                1014
# 73610                       4                  1024                1024
# 73611                       6                   750                1250
# 73612                       3                   328                 328
# 73613                       4                  1024                1024
# 73614                       6                   730                 730
#
#       features_floors  features_unitsOnTheFloor  features_unitFloor
# 73605               0                         0                   0
# 73606               0                         0                   4
# 73607               0                         0                   0
# 73608               0                         0                   0
# 73609               2                         0                   0
# 73610               0                         0                   0
# 73611               0                         0                   0
# 73612               0                         0                   0
# 73613               0                         0                   3
# 73614               3                         1                   0
#
# [10 rows x 21 columns]

# %% [markdown]
# A partir de uma análise mais profunda das informações, vemos que, além dos dados faltantes, há alguns atributos com o tipo*(Dtype)* errados. É o que acontece com os atributos: ***price_price, price_tax_iptu, price_tax_condo, features_usuableAreas, features_totalAreas.***
#
# Podemos ver com mais detalhes abaixo.

# %%
# Verifica o tipo de dataset de cada atributo
dados.dtypes
# Out:
# customerID                   object
# source                       object
# types_unit                   object
# types_usage                  object
# address_city                 object
# address_location_lon        float64
# address_location_lat        float64
# address_zone                 object
# address_neighborhood         object
# prices_price                 object
# prices_tax_iptu              object
# prices_tax_condo             object
# features_bedrooms             int64
# features_bathrooms            int64
# features_suites               int64
# features_parkingSpaces        int64
# features_usableAreas         object
# features_totalAreas          object
# features_floors               int64
# features_unitsOnTheFloor      int64
# features_unitFloor            int64
# dtype: object

# %% [markdown]
# Como vimos anteriormente, há a necessidade de realizar a conversão de alguns tipos de alguns atributos antes de fazer o resumo estatístico.

# %%
#Convertendo os tipos dos atributos que estão errados
dados = dados.astype({
    'prices_price': 'float64',
    'prices_tax_iptu': 'float64',
    'prices_tax_condo': 'float64',
    'features_usableAreas': 'int64',
    'features_totalAreas': 'int64',
})

# Mostra as informações do dataset
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73615 entries, 0 to 73614
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customerID                73615 non-null  object
#  1   source                    73615 non-null  object
#  2   types_unit                73615 non-null  object
#  3   types_usage               73615 non-null  object
#  4   address_city              73615 non-null  object
#  5   address_location_lon      73468 non-null  float64
#  6   address_location_lat      73468 non-null  float64
#  7   address_zone              73615 non-null  object
#  8   address_neighborhood      73615 non-null  object
#  9   prices_price              73615 non-null  float64
#  10  prices_tax_iptu           64499 non-null  float64
#  11  prices_tax_condo          67111 non-null  float64
#  12  features_bedrooms         73615 non-null  int64
#  13  features_bathrooms        73615 non-null  int64
#  14  features_suites           73615 non-null  int64
#  15  features_parkingSpaces    73615 non-null  int64
#  16  features_usableAreas      73615 non-null  int64
#  17  features_totalAreas       73615 non-null  int64
#  18  features_floors           73615 non-null  int64
#  19  features_unitsOnTheFloor  73615 non-null  int64
#  20  features_unitFloor        73615 non-null  int64
# dtypes: float64(5), int64(9), object(7)
# memory usage: 11.8+ MB

# %% [markdown]
# Antes de fazermos o resumo estatístico, é bom salientar que não utilizaremos todos os dados do *dataset*, uma vez que precisamos apenas dos que são imóveis residenciais.
#
# Faremos outro resumo estatístico após tratar os dados.

# %%
# Faz um resumo estatístico do dataset (média, desvio padrão, mínimo, máximo e os quartis)
dados.describe()
# Out:
#        address_location_lon  address_location_lat  prices_price  \
# count          73468.000000          73468.000000  7.361500e+04
# mean             -43.314285            -22.954546  1.210759e+06
# std                0.138098              0.107919  1.384725e+06
# min              -51.075631            -43.519130  4.500000e+04
# 25%              -43.386736            -22.989900  3.990000e+05
# 50%              -43.320145            -22.964210  7.000000e+05
# 75%              -43.211893            -22.923334  1.400000e+06
# max              -22.928173             -8.139998  1.000000e+07
#
#        prices_tax_iptu  prices_tax_condo  features_bedrooms  \
# count     6.449900e+04      6.711100e+04       73615.000000
# mean      4.663216e+03      3.565249e+03           2.573973
# std       2.064977e+05      8.167195e+04           1.281091
# min       0.000000e+00      0.000000e+00           0.000000
# 25%       6.700000e+01      4.090000e+02           2.000000
# 50%       3.900000e+02      8.000000e+02           3.000000
# 75%       1.500000e+03      1.400000e+03           3.000000
# max       2.900000e+07      9.900000e+06          50.000000
#
#        features_bathrooms  features_suites  features_parkingSpaces  \
# count        73615.000000     73615.000000            73615.000000
# mean             2.372397         1.074659                1.408911
# std              1.533557         1.177324                1.727358
# min              0.000000         0.000000                0.000000
# 25%              1.000000         0.000000                1.000000
# 50%              2.000000         1.000000                1.000000
# 75%              3.000000         1.000000                2.000000
# max             49.000000        50.000000              180.000000
#
#        features_usableAreas  features_totalAreas  features_floors  \
# count          73615.000000         7.361500e+04     73615.000000
# mean             141.544359         1.688667e+03         1.931943
# std              146.736952         1.733934e+05         4.528962
# min                0.000000         0.000000e+00         0.000000
# 25%               65.000000         5.800000e+01         0.000000
# 50%               90.000000         8.600000e+01         0.000000
# 75%              158.000000         1.580000e+02         0.000000
# max             1917.000000         2.737500e+07        50.000000
#
#        features_unitsOnTheFloor  features_unitFloor
# count              73615.000000        73615.000000
# mean                   1.220512            1.493514
# std                    3.413755           13.117324
# min                    0.000000            0.000000
# 25%                    0.000000            0.000000
# 50%                    0.000000            0.000000
# 75%                    0.000000            1.000000
# max                   76.000000         1234.000000

# %% [markdown]
# # **4. Preparação dos dados**

# %% [markdown]
# ## 4.1 Filtro

# %% [markdown]
# Primeiro vamos filtrar os dados para aqueles que vamos usar. Nesse caso os imóveis serão residenciais e na cidade do Rio de janeiro.

# %%
#Filtrando pelo tipo de imóvel e a cidade.
filtro = (dados['types_usage'] == 'Residencial') & (dados['address_city'] ==  'Rio de Janeiro')

#Aplicando o filtro
dados = dados[filtro]
dados.head()
# Out:
#         customerID   source   types_unit  types_usage    address_city  \
# 0  775564-BOJSMVON  Website       Outros  Residencial  Rio de Janeiro
# 1  660895-AUENKNYY  Website  Apartamento  Residencial  Rio de Janeiro
# 2  751522-JESYFEQL  Website       Outros  Residencial  Rio de Janeiro
# 4  568886-ZIBFOMCC  Website  Apartamento  Residencial  Rio de Janeiro
# 5  526755-OBLTYTEN  Website       Outros  Residencial  Rio de Janeiro
#
#    address_location_lon  address_location_lat address_zone  \
# 0            -43.413557            -22.909429   Zona Oeste
# 1            -43.509141            -22.869698   Zona Oeste
# 2            -43.646786            -22.986927   Zona Oeste
# 4            -43.480742            -23.027653   Zona Oeste
# 5            -43.571183            -22.966059   Zona Oeste
#
#        address_neighborhood  prices_price  ...  prices_tax_condo  \
# 0                   Taquara       45000.0  ...             150.0
# 1                Santíssimo       45000.0  ...             120.0
# 2        Pedra de Guaratiba       50000.0  ...             100.0
# 4  Recreio dos Bandeirantes       50000.0  ...             400.0
# 5                 Guaratiba       50000.0  ...               0.0
#
#    features_bedrooms  features_bathrooms  features_suites  \
# 0                  0                   0                0
# 1                  2                   1                0
# 2                  0                   0                0
# 4                  3                   2                1
# 5                  0                   0                0
#
#    features_parkingSpaces  features_usableAreas  features_totalAreas  \
# 0                       1                    62                   62
# 1                       1                    44                    0
# 2                       0                   132                  132
# 4                       1                    60                    0
# 5                       0                   200                  200
#
#    features_floors  features_unitsOnTheFloor  features_unitFloor
# 0                0                         0                   0
# 1                0                         0                   0
# 2                0                         0                   0
# 4                3                         4                   2
# 5                0                         0                   0
#
# [5 rows x 21 columns]

# %% [markdown]
# Aplicando o **".info"**, vemos que os dados que não vamos utilizar ainda estão na tabela, por esse motivo é necessário deletá-los e substituir o valor do índice.

# %%
#Verificação do tipo das variáveis e o índice
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 69588 entries, 0 to 73614
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customerID                69588 non-null  object
#  1   source                    69588 non-null  object
#  2   types_unit                69588 non-null  object
#  3   types_usage               69588 non-null  object
#  4   address_city              69588 non-null  object
#  5   address_location_lon      69449 non-null  float64
#  6   address_location_lat      69449 non-null  float64
#  7   address_zone              69588 non-null  object
#  8   address_neighborhood      69588 non-null  object
#  9   prices_price              69588 non-null  float64
#  10  prices_tax_iptu           60863 non-null  float64
#  11  prices_tax_condo          63527 non-null  float64
#  12  features_bedrooms         69588 non-null  int64
#  13  features_bathrooms        69588 non-null  int64
#  14  features_suites           69588 non-null  int64
#  15  features_parkingSpaces    69588 non-null  int64
#  16  features_usableAreas      69588 non-null  int64
#  17  features_totalAreas       69588 non-null  int64
#  18  features_floors           69588 non-null  int64
#  19  features_unitsOnTheFloor  69588 non-null  int64
#  20  features_unitFloor        69588 non-null  int64
# dtypes: float64(5), int64(9), object(7)
# memory usage: 11.7+ MB

# %%
#Deletando dados não usuais e resetando o índice
dados.reset_index(drop=True, inplace=True)
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69588 entries, 0 to 69587
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customerID                69588 non-null  object
#  1   source                    69588 non-null  object
#  2   types_unit                69588 non-null  object
#  3   types_usage               69588 non-null  object
#  4   address_city              69588 non-null  object
#  5   address_location_lon      69449 non-null  float64
#  6   address_location_lat      69449 non-null  float64
#  7   address_zone              69588 non-null  object
#  8   address_neighborhood      69588 non-null  object
#  9   prices_price              69588 non-null  float64
#  10  prices_tax_iptu           60863 non-null  float64
#  11  prices_tax_condo          63527 non-null  float64
#  12  features_bedrooms         69588 non-null  int64
#  13  features_bathrooms        69588 non-null  int64
#  14  features_suites           69588 non-null  int64
#  15  features_parkingSpaces    69588 non-null  int64
#  16  features_usableAreas      69588 non-null  int64
#  17  features_totalAreas       69588 non-null  int64
#  18  features_floors           69588 non-null  int64
#  19  features_unitsOnTheFloor  69588 non-null  int64
#  20  features_unitFloor        69588 non-null  int64
# dtypes: float64(5), int64(9), object(7)
# memory usage: 11.1+ MB

# %% [markdown]
# ## 4.2 Tratamento de dados

# %% [markdown]
# ###Verificação dos valores faltantes

# %%
#Loop para printar cada atributo individualmente
for coluna in dados.columns:
    print('========='*10)
    print(dados[coluna].value_counts())
# Out:
# ==========================================================================================
# customerID
# 775564-BOJSMVON    1
# 569118-JPIGNPUW    1
# 889139-ECOBCGKE    1
# 513790-LDFXVAMH    1
# 782229-AZCMWTNZ    1
#                   ..
# 136267-MVPRYBVB    1
# 197819-AKAPUWEI    1
# 152333-HEVFWYQK    1
# 042353-IJYUMNMW    1
# 610503-VULDJJZZ    1
# Name: count, Length: 69588, dtype: int64
# ==========================================================================================
# source
# Website    69588
# Name: count, dtype: int64
# ==========================================================================================
# types_unit
# Apartamento    59099
# Casa            9299
# Outros          1190
# Name: count, dtype: int64
# ==========================================================================================
# types_usage
# Residencial    69588
# Name: count, dtype: int64
# ==========================================================================================
# address_city
# Rio de Janeiro    69588
# Name: count, dtype: int64
# ==========================================================================================
# address_location_lon
# -43.365895    387
# -43.462590    277
# -43.333066    236
# -43.383834    232
# -43.516473    218
#              ...
# -43.470135      1
# -43.249103      1
# -43.521357      1
# -43.253379      1
# -43.250934      1
# Name: count, Length: 24477, dtype: int64
# ==========================================================================================
# address_location_lat
# -23.000371    387
# -23.017479    277
# -22.937463    236
# -22.966600    232
# -23.015968    218
#              ...
# -22.973647      1
# -22.928118      1
# -22.923647      1
# -22.998584      1
# -22.998918      1
# Name: count, Length: 24240, dtype: int64
# ==========================================================================================
# address_zone
# Zona Oeste      35523
# Zona Sul        18535
# Zona Norte      14379
# Zona Central     1002
#                   149
# Name: count, dtype: int64
# ==========================================================================================
# address_neighborhood
# Barra da Tijuca                 11129
# Recreio dos Bandeirantes         7781
# Copacabana                       6154
# Jacarepaguá                      4018
# Tijuca                           3466
#                                 ...
# Jacarezinho                         2
# Dumas                               1
# Parque Colúmbia                     1
# Área Rural de Rio de Janeiro        1
# Tubiacanga                          1
# Name: count, Length: 152, dtype: int64
# ==========================================================================================
# prices_price
# 650000.0     801
# 550000.0     709
# 750000.0     706
# 1200000.0    682
# 450000.0     681
#             ...
# 508710.0       1
# 505390.0       1
# 501600.0       1
# 504890.0       1
# 9999999.0      1
# Name: count, Length: 4998, dtype: int64
# ==========================================================================================
# prices_tax_iptu
# 0.0       9026
# 1.0       1885
# 20.0      1167
# 10.0      1112
# 100.0      910
#           ...
# 3042.0       1
# 9216.0       1
# 8450.0       1
# 4505.0       1
# 6850.0       1
# Name: count, Length: 5209, dtype: int64
# ==========================================================================================
# prices_tax_condo
# 0.0         5926
# 1200.0      1313
# 800.0       1296
# 1100.0      1222
# 1.0         1209
#             ...
# 81.0           1
# 2591.0         1
# 2924.0         1
# 268000.0       1
# 6075.0         1
# Name: count, Length: 3137, dtype: int64
# ==========================================================================================
# features_bedrooms
# 2     25297
# 3     24027
# 4     10879
# 1      5921
# 5      2207
# 0       623
# 6       453
# 7        82
# 8        47
# 10       16
# 9        15
# 12        5
# 13        4
# 11        2
# 30        2
# 27        2
# 14        2
# 20        1
# 15        1
# 23        1
# 24        1
# Name: count, dtype: int64
# ==========================================================================================
# features_bathrooms
# 2     24962
# 1     18684
# 3     13321
# 4      5458
# 5      3239
# 6      1935
# 7       798
# 0       627
# 8       389
# 9        88
# 10       55
# 11       13
# 12       10
# 15        2
# 20        1
# 17        1
# 25        1
# 24        1
# 16        1
# 22        1
# 13        1
# Name: count, dtype: int64
# ==========================================================================================
# features_suites
# 1     33102
# 0     20595
# 2      7807
# 3      3698
# 4      3309
# 5       909
# 6       136
# 7        16
# 8         5
# 10        4
# 11        2
# 13        2
# 23        1
# 12        1
# 9         1
# Name: count, dtype: int64
# ==========================================================================================
# features_parkingSpaces
# 1      34176
# 2      15295
# 0      11243
# 3       4937
# 4       2657
# 5        574
# 6        349
# 8        114
# 10        83
# 7         79
# 15         9
# 9          8
# 12         8
# 21         7
# 14         6
# 20         6
# 19         6
# 30         4
# 11         4
# 40         3
# 16         3
# 18         2
# 13         2
# 50         2
# 45         2
# 23         1
# 17         1
# 144        1
# 42         1
# 31         1
# 27         1
# 44         1
# 35         1
# 26         1
# Name: count, dtype: int64
# ==========================================================================================
# features_usableAreas
# 70      2156
# 60      1500
# 80      1498
# 90      1272
# 100     1199
#         ...
# 15         1
# 1193       1
# 912        1
# 1031       1
# 942        1
# Name: count, Length: 881, dtype: int64
# ==========================================================================================
# features_totalAreas
# 0        6447
# 70       1950
# 80       1307
# 60       1241
# 90       1108
#          ...
# 1859        1
# 17584       1
# 8915        1
# 31447       1
# 1014        1
# Name: count, Length: 1247, dtype: int64
# ==========================================================================================
# features_floors
# 0     54680
# 12     2042
# 3      1875
# 10     1444
# 5      1067
# 4       978
# 7       947
# 8       925
# 2       807
# 15      709
# 6       707
# 11      413
# 9       358
# 17      333
# 20      309
# 18      308
# 13      300
# 14      280
# 16      274
# 1       250
# 22      185
# 21      103
# 19       87
# 23       73
# 25       44
# 24       26
# 30       22
# 27       11
# 28       10
# 26        8
# 33        4
# 29        4
# 35        2
# 32        1
# 31        1
# 50        1
# Name: count, dtype: int64
# ==========================================================================================
# features_unitsOnTheFloor
# 0     56581
# 4      3551
# 8      1923
# 6      1647
# 2      1419
# 10     1124
# 12      976
# 1       909
# 3       324
# 5       313
# 19      146
# 7       142
# 9       139
# 16       84
# 11       66
# 14       48
# 15       36
# 18       31
# 13       31
# 20       28
# 17       14
# 25       12
# 23        8
# 24        7
# 50        5
# 26        4
# 30        4
# 40        3
# 21        3
# 27        2
# 45        2
# 36        1
# 39        1
# 35        1
# 28        1
# 34        1
# 22        1
# Name: count, dtype: int64
# ==========================================================================================
# features_unitFloor
# 0       51776
# 2        3108
# 3        2826
# 1        2475
# 4        1730
# 5        1466
# 6        1249
# 7         969
# 8         841
# 10        772
# 9         520
# 12        394
# 11        337
# 15        233
# 13        168
# 14        160
# 16        136
# 17        107
# 18         66
# 20         60
# 19         43
# 21         38
# 22         31
# 25         15
# 50         12
# 24          8
# 23          8
# 1234        7
# 26          5
# 28          4
# 99          3
# 42          3
# 29          2
# 27          2
# 60          1
# 701         1
# 302         1
# 370         1
# 123         1
# 480         1
# 167         1
# 102         1
# 78          1
# 30          1
# 504         1
# 32          1
# 65          1
# 43          1
# Name: count, dtype: int64

# %% [markdown]
# Nessa linha de código abaixo verifica a quantidade de valores nulos no *dataset*.

# %%
# verificando nulls no dataset
dados.isnull().sum()
# Out:
# customerID                     0
# source                         0
# types_unit                     0
# types_usage                    0
# address_city                   0
# address_location_lon         139
# address_location_lat         139
# address_zone                   0
# address_neighborhood           0
# prices_price                   0
# prices_tax_iptu             8725
# prices_tax_condo            6061
# features_bedrooms              0
# features_bathrooms             0
# features_suites                0
# features_parkingSpaces         0
# features_usableAreas           0
# features_totalAreas            0
# features_floors                0
# features_unitsOnTheFloor       0
# features_unitFloor             0
# dtype: int64

# %% [markdown]
# ### Tratando os valores vazios na zona

# %% [markdown]
# A partir da verificação dos dados vemos que no atributo zona, há valores vazio e não nulos. Como há todos os bairros e ele está diretamente ligado com a zona, podemos verificar a partir do bairro qual será a zona faltante.

# %%
#Substituindo as células vazias do atributo zona por NaN
dados['address_zone'] = dados['address_zone'].replace('', np.nan)

# %%
#verificação dos números nulos
dados.address_zone.isnull().sum()
# Out:
# 149

# %%
#Relaciona a zona e o bairro. Neste caso, remove-se as duplicatas.
dici = dados[~dados['address_zone'].isna()].drop_duplicates(subset=['address_neighborhood']).to_dict('records')

# %%
#Cria um dicionário relacionando bairro e zona.
dic_zonas = {dic['address_neighborhood']: dic['address_zone'] for dic in dici}
print(dic_zonas)
# Out:
# {'Taquara': 'Zona Oeste', 'Santíssimo': 'Zona Oeste', 'Pedra de Guaratiba': 'Zona Oeste', 'Recreio dos Bandeirantes': 'Zona Oeste', 'Guaratiba': 'Zona Oeste', 'Jacarezinho': 'Zona Norte', 'Santa Cruz': 'Zona Oeste', 'Vargem Grande': 'Zona Oeste', 'Bangu': 'Zona Oeste', 'Tanque': 'Zona Oeste', 'Santo Cristo': 'Zona Central', 'Coelho Neto': 'Zona Norte', 'Bento Ribeiro': 'Zona Norte', 'Campo Grande': 'Zona Oeste', 'Oswaldo Cruz': 'Zona Norte', 'Camorim': 'Zona Oeste', 'Sepetiba': 'Zona Oeste', 'Vigário Geral': 'Zona Norte', 'Campinho': 'Zona Norte', 'Realengo': 'Zona Oeste', 'Jacarepaguá': 'Zona Oeste', 'Cidade de Deus': 'Zona Oeste', 'Honório Gurgel': 'Zona Norte', 'Centro': 'Zona Central', 'Cosmos': 'Zona Oeste', 'Tomás Coelho': 'Zona Norte', 'Cascadura': 'Zona Norte', 'Pavuna': 'Zona Norte', 'Paciência': 'Zona Oeste', 'Praça Seca': 'Zona Oeste', 'Vila Valqueire': 'Zona Oeste', 'Inhoaíba': 'Zona Oeste', 'Vicente de Carvalho': 'Zona Norte', 'Senador Vasconcelos': 'Zona Oeste', 'Turiaçu': 'Zona Norte', 'Penha Circular': 'Zona Norte', 'Quintino Bocaiúva': 'Zona Norte', 'Sampaio': 'Zona Norte', 'Piedade': 'Zona Norte', 'Braz de Pina': 'Zona Norte', 'São Cristóvão': 'Zona Norte', 'Marechal Hermes': 'Zona Norte', 'Santa Teresa': 'Zona Sul', 'Vila Isabel': 'Zona Norte', 'Curicica': 'Zona Oeste', 'Engenho de Dentro': 'Zona Norte', 'Engenho da Rainha': 'Zona Norte', 'Madureira': 'Zona Norte', 'Engenho Novo': 'Zona Norte', 'Engenheiro Leal': 'Zona Norte', 'Higienópolis': 'Zona Norte', 'Padre Miguel': 'Zona Oeste', 'Rocha Miranda': 'Zona Norte', 'Pilares': 'Zona Norte', 'Anchieta': 'Zona Norte', 'Jardim Sulacap': 'Zona Oeste', 'Encantado': 'Zona Norte', 'Galeão': 'Zona Norte', 'Parada de Lucas': 'Zona Norte', 'Olaria': 'Zona Norte', 'Bonsucesso': 'Zona Norte', 'Méier': 'Zona Norte', 'Laranjeiras': 'Zona Sul', 'Cordovil': 'Zona Norte', 'Abolição': 'Zona Norte', 'Inhaúma': 'Zona Norte', 'Bancários': 'Zona Norte', 'Lins de Vasconcelos': 'Zona Norte', 'Ramos': 'Zona Norte', 'Irajá': 'Zona Norte', 'Rio Comprido': 'Zona Sul', 'Guadalupe': 'Zona Norte', 'Penha': 'Zona Norte', 'Riachuelo': 'Zona Norte', 'Tijuca': 'Zona Norte', 'Pechincha': 'Zona Oeste', 'Vaz Lobo': 'Zona Norte', 'Freguesia (Ilha do Governador)': 'Zona Norte', 'Cavalcanti': 'Zona Norte', 'Senador Camará': 'Zona Oeste', 'Vargem Pequena': 'Zona Oeste', 'Praça da Bandeira': 'Zona Norte', 'Vila Kosmos': 'Zona Norte', 'Catete': 'Zona Sul', 'Rocha': 'Zona Norte', 'Colégio': 'Zona Norte', 'Del Castilho': 'Zona Norte', 'Grajaú': 'Zona Norte', 'Barra de Guaratiba': 'Zona Oeste', 'Anil': 'Zona Oeste', 'Andaraí': 'Zona Norte', 'Vila da Penha': 'Zona Norte', 'Magalhães Bastos': 'Zona Oeste', 'Barra da Tijuca': 'Zona Oeste', 'Freguesia (Jacarepaguá)': 'Zona Oeste', 'Copacabana': 'Zona Sul', 'São Francisco Xavier': 'Zona Norte', 'Água Santa': 'Zona Norte', 'Itanhangá': 'Zona Oeste', 'Jardim América': 'Zona Norte', 'Portuguesa': 'Zona Norte', 'Vidigal': 'Zona Sul', 'Cachambi': 'Zona Norte', 'Tauá': 'Zona Norte', 'Maria da Graça': 'Zona Norte', 'Gardênia Azul': 'Zona Oeste', 'Catumbi': 'Zona Sul', 'Jacaré': 'Zona Norte', 'Todos os Santos': 'Zona Norte', 'Praia da Bandeira': 'Zona Norte', 'Cocotá': 'Zona Norte', 'Botafogo': 'Zona Sul', 'Paquetá': 'Zona Norte', 'Caju': 'Zona Norte', 'Benfica': 'Zona Norte', 'Cidade Nova': 'Zona Central', 'Glória': 'Zona Sul', 'Flamengo': 'Zona Sul', 'Cacuia': 'Zona Norte', 'Jardim Carioca': 'Zona Norte', 'Maracanã': 'Zona Norte', 'Vista Alegre': 'Zona Norte', 'Estácio': 'Zona Central', 'Jardim Guanabara': 'Zona Norte', 'Leme': 'Zona Sul', 'Vila Militar': 'Zona Oeste', 'Dumas': 'Zona Oeste', 'Mangueira': 'Zona Norte', 'Moneró': 'Zona Norte', 'Pitangueiras': 'Zona Norte', 'Ribeira': 'Zona Norte', 'Saúde': 'Zona Central', 'Leblon': 'Zona Sul', 'Gamboa': 'Zona Central', 'Campo dos Afonsos': 'Zona Oeste', 'Zumbi': 'Zona Norte', 'Alto da Boa Vista': 'Zona Norte', 'Ricardo de Albuquerque': 'Zona Norte', 'Parque Anchieta': 'Zona Norte', 'Gávea': 'Zona Sul', 'Jardim Botâni ...

# %%
#Loop que atribui o valor à zona com base no bairro.
for bairro,zona in dic_zonas.items():
  dados.loc[dados['address_neighborhood'] == bairro, 'address_zone'] = zona

# %%
#Verificação dos números nulos
dados['address_zone'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Tratando valores faltantes na taxa de IPTU e Condomínio

# %%
#Verificação dos valores faltantes da taxa de condomínio
dados['prices_tax_condo'].isnull().sum()
# Out:
# 6061

# %%
#Verificação dos valores faltantes da taxa de IPTU
dados['prices_tax_iptu'].isnull().sum()
# Out:
# 8725

# %% [markdown]
# Bom, poderiamos utilizar a mesma lógica de substituição como fizemos para a zona. Porém, esses valores são muito relativos de rua por rua.
#
# Nesse caso, há duas opções que são:
#
#
# *   Excluir os valores faltantes.
# *   Assumir que esses valores são zero.
#
# Após análises, assumimos que é melhor deixar esses valores como zero. Assim, temos que substituir esses valores faltantes com zero.

# %%
dados.prices_tax_iptu.fillna(0, inplace=True)
dados.prices_tax_condo.fillna(0, inplace=True)

# %%
#Verificação dos valores faltantes da taxa de condomínio
dados['prices_tax_condo'].isnull().sum()
# Out:
# 0

# %%
#Verificação dos valores faltantes da taxa de IPTU
dados['prices_tax_iptu'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## 4.3 Selecionando as variáveis

# %% [markdown]
# Poderiamos ter feito isso antes, porém para manter a sequência lógica do tratamento de dados, achou-se conveniente fazer esse tratamento agora.
#
# Como falamos na descrição do problema, vamos utilizar apenas 14 dos 21 atributos do *dataset*.

# %%
#Exclusão dos atributos que não serão necessários
dados.drop(['customerID', 'source', 'types_usage', 'address_city',
                    'address_location_lon', 'address_location_lat','address_neighborhood' ], axis = 1, inplace=True)

# %% [markdown]
# ### Renomeando as variáveis

# %%
dicionario_atributos = {'types_unit': 'tipo', 'address_zone': 'zona', 'prices_price': 'preco',
                     'prices_tax_condo': 'taxa_condo', 'prices_tax_iptu': 'taxa_iptu', 'features_bedrooms': 'quartos',
                      'features_bathrooms': 'banheiros', 'features_suites': 'suites', 'features_parkingSpaces': 'vagas_estac',
                      'features_usableAreas': 'areas_usuais', 'features_totalAreas':'area_total', 'features_floors':'andares',
                      'features_unitsOnTheFloor':'imov_por_andar', 'features_unitFloor':'andar_imovel'}

dados = dados.rename(dicionario_atributos, axis = 1)
dados.head()
# Out:
#           tipo        zona    preco  taxa_iptu  taxa_condo  quartos  \
# 0       Outros  Zona Oeste  45000.0        0.0       150.0        0
# 1  Apartamento  Zona Oeste  45000.0        0.0       120.0        2
# 2       Outros  Zona Oeste  50000.0        0.0       100.0        0
# 3  Apartamento  Zona Oeste  50000.0      120.0       400.0        3
# 4       Outros  Zona Oeste  50000.0        0.0         0.0        0
#
#    banheiros  suites  vagas_estac  areas_usuais  area_total  andares  \
# 0          0       0            1            62          62        0
# 1          1       0            1            44           0        0
# 2          0       0            0           132         132        0
# 3          2       1            1            60           0        3
# 4          0       0            0           200         200        0
#
#    imov_por_andar  andar_imovel
# 0               0             0
# 1               0             0
# 2               0             0
# 3               4             2
# 4               0             0

# %%
#Verificação de dados faltantes
dados.isnull().sum()
# Out:
# tipo              0
# zona              0
# preco             0
# taxa_iptu         0
# taxa_condo        0
# quartos           0
# banheiros         0
# suites            0
# vagas_estac       0
# areas_usuais      0
# area_total        0
# andares           0
# imov_por_andar    0
# andar_imovel      0
# dtype: int64

# %% [markdown]
# ## 4.3 Vizualições Unimodais e Multimodais

# %% [markdown]
# Como ja tratamos os dados, vamos realizar novamente o resumo estatístico e verificar por vizualizações unimodais e multimodais.

# %%
#Resumo estatístico
dados.describe()
# Out:
#               preco     taxa_iptu    taxa_condo       quartos     banheiros  \
# count  6.958800e+04  6.958800e+04  6.958800e+04  69588.000000  69588.000000
# mean   1.233982e+06  3.829974e+03  3.301126e+03      2.693970      2.423952
# std    1.390898e+06  1.785407e+05  7.943358e+04      1.077059      1.470166
# min    4.500000e+04  0.000000e+00  0.000000e+00      0.000000      0.000000
# 25%    4.199998e+05  0.000000e+00  2.500000e+02      2.000000      1.000000
# 50%    7.350000e+05  2.500000e+02  7.500000e+02      3.000000      2.000000
# 75%    1.450000e+06  1.210000e+03  1.300000e+03      3.000000      3.000000
# max    1.000000e+07  2.900000e+07  9.900000e+06     30.000000     25.000000
#
#              suites   vagas_estac  areas_usuais    area_total       andares  \
# count  69588.000000  69588.000000   69588.00000  6.958800e+04  69588.000000
# mean       1.130813      1.425605     141.40632  1.772376e+03      1.941499
# std        1.150009      1.460542     138.95235  1.783384e+05      4.496438
# min        0.000000      0.000000       0.00000  0.000000e+00      0.000000
# 25%        0.000000      1.000000      68.00000  6.000000e+01      0.000000
# 50%        1.000000      1.000000      92.00000  8.900000e+01      0.000000
# 75%        1.000000      2.000000     160.00000  1.590000e+02      0.000000
# max       23.000000    144.000000    1911.00000  2.737500e+07     50.000000
#
#        imov_por_andar  andar_imovel
# count    69588.000000  69588.000000
# mean         1.155558      1.489926
# std          2.979235     13.461909
# min          0.000000      0.000000
# 25%          0.000000      0.000000
# 50%          0.000000      0.000000
# 75%          0.000000      1.000000
# max         50.000000   1234.000000

# %% [markdown]
# ### Histograma

# %% [markdown]
# Vemos que os atributos ***preco, banheiros, suites e areas_usuais*** seguem uma distribuição exponencial.

# %%
# Histograma
dados.hist(figsize = (15,10))
plt.show()

# %% [markdown]
# ### Mapa de calor

# %% [markdown]
# Vamos utilizar o HeatMap para verificar a correlação entre as variáveis.

# %%
#visualização das correlações
dados_numericos = dados.select_dtypes(include=[float, int])
correlacao = dados_numericos.corr()
# Matriz de Correlação com Matplotlib Seaborn
f, ax = plt.subplots(figsize=(13, 8))
ax = sns.heatmap(correlacao, cmap='RdBu', square=True, fmt='.2f', annot=True)
ax.set_title('Correlação entre variáveis', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Correlação entre variáveis')

# %%
# Scatter Plot com Seaborn - Variação 2

#sns.pairplot(dados, hue = "price", height = 2.5);

# %% [markdown]
# Vamos plotar o gráfico do preço para analisarmos melhor a distribuição.

# %%
# Criar o histograma personalizado
ax = sns.histplot(data=dados, x='preco', kde=True, color='skyblue', bins=30)

# Ajustar o layout
ax.figure.set_size_inches(20, 10)
ax.set_title('Histograma de Preços', fontsize=20)
ax.set_xlabel('Preço', fontsize=16)
ax.set_ylabel('Frequência', fontsize=16)

# Adicionar valores em cada barra
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2,
            height + 0.5,  # Posicionar um pouco acima da barra
            f'{int(height)}',  # Valor da frequência arredondado
            ha="center", fontsize=12)

# Customizar o kde (linha de densidade)
sns.kdeplot(data=dados['preco'], ax=ax, color='red', lw=3, linestyle='--')

# Adicionar grades
plt.grid(True)

# Exibir o gráfico
plt.show()

# %% [markdown]
# ## 4.4 Treino e teste dos dados

# %% [markdown]
# ## **Transformações**

# %% [markdown]
# Verificamos que a curva de preço é assimétrica e analisando os dados, decidimos normalizar, uma vez que isso afetará diretamente as previsões para casas de alto valor.
#
# Para isso, vamos utilizar a transformação logarítmica para obtermos uma distribuição mais próxima da normal. A transformação será:
#
# $$log1p = log(1+x)$$
#
# É válido lembrar que será necessário realizar a transformação inversa para obter o valor original. Para isso vamos utilizar a equação abaixo:
#
#
# $$expm1 = exp(x) - 1$$

# %%
transformer = FunctionTransformer(np.log1p, validate=True)
dados_transformados = transformer.transform(dados.select_dtypes(exclude=['object']))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:486: UserWarning: X has feature names, but FunctionTransformer was fitted without feature names
#   warnings.warn(

# %%
colunas_dados_tranformados = dados.select_dtypes(exclude=['object']).columns

df_transformado = pd.concat([dados.select_dtypes(include=['object']), pd.DataFrame(dados_transformados, columns=colunas_dados_tranformados)], axis=1)
df_transformado.head()
# Out:
#           tipo        zona      preco  taxa_iptu  taxa_condo   quartos  \
# 0       Outros  Zona Oeste  10.714440   0.000000    5.017280  0.000000
# 1  Apartamento  Zona Oeste  10.714440   0.000000    4.795791  1.098612
# 2       Outros  Zona Oeste  10.819798   0.000000    4.615121  0.000000
# 3  Apartamento  Zona Oeste  10.819798   4.795791    5.993961  1.386294
# 4       Outros  Zona Oeste  10.819798   0.000000    0.000000  0.000000
#
#    banheiros    suites  vagas_estac  areas_usuais  area_total   andares  \
# 0   0.000000  0.000000     0.693147      4.143135    4.143135  0.000000
# 1   0.693147  0.000000     0.693147      3.806662    0.000000  0.000000
# 2   0.000000  0.000000     0.000000      4.890349    4.890349  0.000000
# 3   1.098612  0.693147     0.693147      4.110874    0.000000  1.386294
# 4   0.000000  0.000000     0.000000      5.303305    5.303305  0.000000
#
#    imov_por_andar  andar_imovel
# 0        0.000000      0.000000
# 1        0.000000      0.000000
# 2        0.000000      0.000000
# 3        1.609438      1.098612
# 4        0.000000      0.000000

# %% [markdown]
# ### Mapa de calor

# %% [markdown]
# Novo mapa de calor para verificar a correlação dos atributos, uma vez que fizemos a transformação, é necessário analisar novamente,

# %%
#Visualização das correlações
numericos = df_transformado.select_dtypes(include=[float, int])
correlacao_transformado = numericos.corr()
# Matriz de Correlação com Matplotlib Seaborn
f, ax = plt.subplots(figsize=(13, 8))
ax = sns.heatmap(correlacao_transformado, cmap='RdBu',  square=True, fmt='.2f', annot=True)
ax.set_title('Correlação entre variáveis - Tranformação Log', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Correlação entre variáveis - Tranformação Log')

# %% [markdown]
# ### Transformando variáveis

# %% [markdown]
# Para conseguir prosseguirmos com a análise, temos que transformar o tipo de algumas variáveis. As colunas ***type*** e ***zone*** são do tipo objeto e por isso não há como treinar o modelo delas. E como são variáveis importantes para prever o preço dos imóveis, temos que considerá-los.
#
# Para isso vamos utilizar a função dummies que consiste na transformação das variáveis categóricas a partir da criação de novas colunas a partir das categorias. Cada uma delas se torna uma nova coluna e o valor na linha correspondente será 1, caso tenha a presença da característica. Do contrário, será 0.
#
# ![dummies.PNG](data:image/png;base64,...)

# %%
#Separando as variáveis do tipo objeto
variaveis_objeto = dados.select_dtypes(include=['object']).columns

#Criando variáveis dummies
df_dummies = pd.get_dummies(dados[variaveis_objeto])

#Concatenando com o conjunto de dados sem os atributos do tipo objeto
dados_numericos = pd.concat([dados.drop(variaveis_objeto, axis=1), df_dummies], axis=1)
dados_numericos.head()
# Out:
#      preco  taxa_iptu  taxa_condo  quartos  banheiros  suites  vagas_estac  \
# 0  45000.0        0.0       150.0        0          0       0            1
# 1  45000.0        0.0       120.0        2          1       0            1
# 2  50000.0        0.0       100.0        0          0       0            0
# 3  50000.0      120.0       400.0        3          2       1            1
# 4  50000.0        0.0         0.0        0          0       0            0
#
#    areas_usuais  area_total  andares  imov_por_andar  andar_imovel  \
# 0            62          62        0               0             0
# 1            44           0        0               0             0
# 2           132         132        0               0             0
# 3            60           0        3               4             2
# 4           200         200        0               0             0
#
#    tipo_Apartamento  tipo_Casa  tipo_Outros  zona_Zona Central  \
# 0             False      False         True              False
# 1              True      False        False              False
# 2             False      False         True              False
# 3              True      False        False              False
# 4             False      False         True              False
#
#    zona_Zona Norte  zona_Zona Oeste  zona_Zona Sul
# 0            False             True          False
# 1            False             True          False
# 2            False             True          False
# 3            False             True          False
# 4            False             True          False

# %% [markdown]
# ### Treinando e testando

# %%
#Variáveis independentes
X = dados_numericos.drop('preco', axis=1)

#Variável dependente
y = dados_numericos['preco']

#Divisão em conjunto de treino e teste
X_treino, X_teste, y_treino, y_teste = train_test_split(X, y, test_size=0.25, random_state=42)

# %% [markdown]
# # **5. Regressão linear**

# %%
#Instanciando o modelo
modelo = LinearRegression()

#Treinando o conjunto de dados
modelo.fit(X_treino, y_treino)

#Prevendo o modelo
y_pred = model.predict(X_teste)

#Exibindo o resultado
print(y_pred)
# Out:
# [ 553547.04563822   15449.19817618  758620.8573178  ...  -11061.23884495
#  1348195.88902784   87506.37487299]

# %%
#Prediz os valores de y para os dados de treino.
y_treino_pred = modelo.predict(X_treino)
#Prediz os valores de y para os dados de teste.
y_teste_pred = modelo.predict(X_teste)

# %% [markdown]
# ### Métricas de desempenho

# %% [markdown]
# Há algumas métricas para verificar o desempenho do modelo. Os observados neste notebook serão:
#
# **Erro quadrático médio:**
#
# ![mse.PNG](data:image/png;base64,...)
#
# **Coeficiente de determinação:**
#
# ![mse.PNG](data:image/png;base64,...)

# %%
treino_error = mean_squared_error(y_treino, y_treino_pred)
test_error = mean_squared_error(y_teste, y_teste_pred)
r2 = r2_score(y_teste, y_pred)
print("Coeficiente de determinação:", r2)
print("Erro médio quadrático treino:", treino_error)
print("Erro médio quadrático teste:", test_error)
# Out:
# Coeficiente de determinação: 0.6731182121604884
# Erro médio quadrático treino: 659932609944.8013
# Erro médio quadrático teste: 622605848485.1106

# %%
fig, ax = plt.subplots(figsize=(8, 8))
pev = PredictionError(modelo)
pev.fit(X_treino, y_treino)
pev.score(X_teste, y_teste)
pev.poof()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# <Axes: title={'center': 'Prediction Error for LinearRegression'}, xlabel='$y$', ylabel='$\\hat{y}$'>

# %% [markdown]
# # **6. Árvore de decisão**

# %%
#Instanciando o modelo
arvore = DecisionTreeRegressor(random_state=42, max_depth=5)

#Treinando o modelo
arvore.fit(X_treino, y_treino)

#Testando o modelo
previsao_arvore = arvore.predict(X_teste)

#Exibindo o modelo
print(previsao_arvore)
# Out:
# [536524.53447043 315501.49389567 552506.91631799 ... 315501.49389567
#  997753.39567083 315501.49389567]

# %% [markdown]
# ###Métrica de desempenho

# %%
#Coeficiente de determinação
r2_arvore = r2_score(y_teste, previsao_arvore)
print("Coeficiente de determinação:", r2_arvore)

# %%
fig, ax = plt.subplots(figsize=(8, 8))
pev = PredictionError(arvore)
pev.fit(X_treino, y_treino)
pev.score(X_teste, y_teste)
pev.poof()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# <Axes: title={'center': 'Prediction Error for DecisionTreeRegressor'}, xlabel='$y$', ylabel='$\\hat{y}$'>

# %% [markdown]
# # **7. Random Forest**

# %% [markdown]
# É bom ficar atento aos parâmetros que serão usados. E também é bom saber que este modelo de regressão demanda mais poder computacional. Há a biblioteca para caso de dúvidas.
#
# [Random Florest](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html#sklearn.ensemble.RandomForestRegressor)

# %%
floresta = RandomForestRegressor(random_state=42, max_depth=None, n_estimators=10)

floresta.fit(X_treino, y_treino)

previsao_floresta = floresta.predict(X_teste)

# %% [markdown]
# ### Métricas de desempenho

# %%
#coeficiente de determinacao
r2_floresta = r2_score(y_teste, previsao_floresta)
print("Coeficiente de determinação:", r2_floresta)
# Out:
# Coeficiente de determinação: 0.8512741009186436

# %%
fig, ax = plt.subplots(figsize=(8, 8))
pev = PredictionError(floresta)
pev.fit(X_treino, y_treino)
pev.score(X_teste, y_teste)
pev.poof()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# <Axes: title={'center': 'Prediction Error for RandomForestRegressor'}, xlabel='$y$', ylabel='$\\hat{y}$'>
